# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear Regression
#
# In this lab, we are going to implement a Linear Regression model "by hand" and also use sklearn to implement linear regressors using different basis functions, and then add regularization to the models.

# %% [markdown]
# ## Part 1 - Synthetic and real datasets
#
# * Generate 50 points in a line in the interval $[0, 10]$ for `x`, perturbed by a small gaussian noise. For example, `y = 2 * x + 5 + noise` where `noise` is taken from a normal distribution.
# * plot the generated data as a scatter plot, and the line without noise as a reference
#
# *Note:* If you want to generate the same data as I generated, use $y = 3x + 5 + \epsilon$ after setting the random seed to 0

# %%
# your code here
rng=np.random.default_rng(0)
x=np.linspace(0,11,50)
noise=rng.normal(0,1,50)
y=3*x+5
y_noise=y+noise
plt.scatter(x,y_noise)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Load the housing dataset
#
# For this lab we will be using the raw version of the Housing dataset.
#
# **Housing.txt:** this dataset is constituted by 506 points in 14 dimensions. Each point represents a house in the Boston area, and the 14 attributes that you find orderly in each column are the following:
# * `CRIM` - per capita crime rate by town
# * `ZN` - proportion of residential land zoned for lots over 25,000 sq.ft.
# * `INDUS` - proportion of non-retail business acres per town.
# * `CHAS` - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * `NOX` - nitric oxides concentration (parts per 10 million)
# * `RM` - average number of rooms per dwelling
# * `AGE` - proportion of owner-occupied units built prior to 1940
# * `DIS` - weighted distances to five Boston employment centres
# * `RAD` - index of accessibility to radial highways
# * `TAX` - full-value property-tax rate per \$10,000
# * `PTRATIO` - pupil-teacher ratio by town
# * `B` - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * `LSTAT` - % lower status of the population
# * `MEDV` - Median value of owner-occupied homes in $1000's
#
# This dataset is normally associated with 2 regression tasks: predicting `NOX` (in which the nitrous oxide level is to be predicted); and predicting price `MEDV` (in which the median value of a home is to be predicted).

# %%
housing_names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
housing=(housing-housing.mean())/housing.std()
housing
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Edilson\AppData\Local\Temp\ipykernel_2112\1438242658.py:2: SyntaxWarning: invalid escape sequence '\s'
#   housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419367  0.284548 -1.286636 -0.272329 -0.144075  0.413263 -0.119895
# 1   -0.416927 -0.487240 -0.592794 -0.272329 -0.739530  0.194082  0.366803
# 2   -0.416929 -0.487240 -0.592794 -0.272329 -0.739530  1.281446 -0.265549
# 3   -0.416338 -0.487240 -1.305586 -0.272329 -0.834458  1.015298 -0.809088
# 4   -0.412074 -0.487240 -1.305586 -0.272329 -0.834458  1.227362 -0.510674
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.412820 -0.487240  0.115624 -0.272329  0.157968  0.438881  0.018654
# 502 -0.414839 -0.487240  0.115624 -0.272329  0.157968 -0.234316  0.288648
# ...

# %% [markdown]
# ## Part 2 -- Build Linear Regression Models
#
# You will need to implement it twice:
#
# 1. using the Normal Equations seen in class (Moore-Penrose pseudo-inverse)
# 2. using stochastic gradient descent
#
# * **Tip 1:** When you implement the stochastic gradient version it will be crucial to plot the sum of squares error as a function of the iteration
# * **Tip 2:** You will need to initialize the weights. Start by choosing them randomly, Gaussian distributed, with a very small variance...
#
# Run some experiments with your stochastic gradient descent version, and think about these questions:
# * what happens with different values of the step parameter?
# * Does the system always converge to the same solution?
# * Are you getting the same solution that you get with the closed form implementation?
# * What happens if you initialize your weights to values that are too big?
#
# Below, I provide some skeletons for your implementations, but feel free to structure your code differently.
#
# Remember to:
# * Separate the datasets into training and testing (I used 60% for training)

# %%
def linear_regression_PI(X, y):
    """
    Implements a Linear Regression model using the Moore-Penrose pseudo-inverse
    
    Parameters
    ----------
    X : array
        A 2-dimensional array with samples in the rows and features in the columns
    y : array
        An array with the same number of  as samples in X, the values to predict
    
    Returns
    -------
    w : array
        Learnt parameters
        
    Notes
    -----
    The first column of w corresponds to the bias (`w_0`)
    """
    # your code here

    M=X.shape[1]
    N=y.size
    fi=np.zeros(shape=(N,M+1))
    fi[:,0]=np.ones_like(X[:,0])
    fi[:,1:]=X
    w=np.linalg.solve(fi.T@fi,fi.T@y)
    return w
    


def linear_regression_SGD(X, y, lr, max_iter=10):
    """
    Implements a Linear Regression model using Stochastic Gradient Descent
    
    Parameters
    ----------
    X : array
        A 2-dimensional array with samples in the rows and features in the columns
    y : array
        An array with the same number of  as samples in X, the values to predict
    lr : float
        Learning rate
    max_iter : int
        number of epochs to use for the gradient descent
    
    Returns
    -------
    w : array
        Learnt parameters
    sse_history : array
        An array that contains the error of the model in every iteration
    Notes
    -----
    This function uses the gradient of the sum of squares function (Equations 3.12, and 3.23 in the Bishop book)
    """
    # your code here
    M=X.shape[1]
    N=y.size
    fi=np.zeros(shape=(N,M+1))
    fi[:,0]=np.ones_like(X[:,0])
    fi[:,1:]=X
    w=np.random.rand(X.shape[1]+1)
    for i in range(max_iter):
        w=w+lr*(fi.T)@(y-fi@w)
    return w

# %% [markdown]
# we can now use this function to learn the parameters for predicting `NOX`

# %% [markdown]
# First you will have to prepare the data:
# - Separate the features from the target variables (Put the features in a matrix X and the target variable in a vector y)
# - Split the data using sklearn's train_test_split.

# %%
# your code here
housing_names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
housing=(housing-housing.mean())/housing.std()
from sklearn.model_selection import train_test_split
y=np.array(housing["NOX"].copy())
housing=housing.drop(["NOX"],axis=1)
X=np.array(housing)
X_train,X_test,y_train,y_test=train_test_split(X,y)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Edilson\AppData\Local\Temp\ipykernel_2112\10959510.py:3: SyntaxWarning: invalid escape sequence '\s'
#   housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')

# %% [markdown]
# Now use the functions you coded to learn the weights!

# %%
# your code here
w_pi=linear_regression_PI(X_test,y_test)
w_sgd=linear_regression_SGD(X_test,y_test,0.001,600)

# %% [markdown]
# make a plot that shows the evolution of the sum of squares error
#
# **tip:** make it a callable function that you can reuse for the next task

# %%
# your code here
import matplotlib.pyplot as plt
def plot_errors(X,y,lr,max_iter):
    M=X.shape[1]
    N=y.size
    fi=np.zeros(shape=(N,M+1))
    fi[:,0]=np.ones_like(X[:,0])
    fi[:,1:]=X
    w=np.zeros(X.shape[1]+1)
    errors=[]
    for i in range(max_iter):
        w=w+lr*(fi.T)@(y-fi@w)
        errors.append((np.sum((y-fi@w)**2))/2)
    plt.plot(errors)
    plt.xlim(0,max_iter)
    plt.ylim(0)
    plt.show()

# %% [markdown]
# Use the learn weights to make predictions for the test set, and evaluate the model using the root mean squared error (remember that the bias is the first column of the weight matrix)
# - You can use the function you coded for your coursework, but feel free to use sklearn's `mean_squared_error()` here

# %%
# your code here
from sklearn.metrics import mean_squared_error
y_pred_pi=w_pi[0]+X_test@w_pi[1:]
y_pred_sgd=w_sgd[0]+X_test@w_pi[1:]
def mse(y_real,y_pred):
    return ((y_real-y_pred)**2).sum()/y_pred.size
print(mse(y_test,y_pred_pi))
print(mse(y_test,y_pred_sgd))
# Out:
# 0.19972379159109815
# 0.19972380239148868

# %% [markdown]
# Repeat the same analysis for predicting `MEDV`

# %%
# your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
housing_names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
housing=(housing-housing.mean())/housing.std()
from sklearn.model_selection import train_test_split
y=np.array(housing["NOX"].copy())
housing=housing.drop(["NOX"],axis=1)
housing=housing.drop(["MEDV"],axis=1)
X=np.array(housing)
X_train,X_test,y_train,y_test=train_test_split(X,y)

w_pi=linear_regression_PI(X_test,y_test)
w_sgd=linear_regression_SGD(X_test,y_test,0.001,600)

def plot_errors(X,y,lr,max_iter):
    M=X.shape[1]
    N=y.size
    fi=np.zeros(shape=(N,M+1))
    fi[:,0]=np.ones_like(X[:,0])
    fi[:,1:]=X
    w=np.zeros(X.shape[1]+1)
    errors=[]
    for i in range(max_iter):
        w=w+lr*(fi.T)@(y-fi@w)
        errors.append((np.sum((y-fi@w)**2))/2)
    plt.plot(errors)
    plt.xlim(0,max_iter)
    plt.ylim(0)
    plt.show()
plot_errors(X_test,y_test,0.001,100)

from sklearn.metrics import mean_squared_error
y_pred_pi=w_pi[0]+X_test@w_pi[1:]
y_pred_sgd=w_sgd[0]+X_test@w_pi[1:]
def mse(y_real,y_pred):
    return ((y_real-y_pred)**2).sum()/y_pred.size
print(mse(y_test,y_pred_pi))
print(mse(y_test,y_pred_sgd))
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Edilson\AppData\Local\Temp\ipykernel_6664\1530473777.py:6: SyntaxWarning: invalid escape sequence '\s'
#   housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
# C:\Users\Edilson\AppData\Local\Temp\ipykernel_6664\1530473777.py:6: SyntaxWarning: invalid escape sequence '\s'
#   housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[112], line 6
#       4 import matplotlib.pyplot as plt
#       5 housing_names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
# ----> 6 housing = pd.read_table("data/housing.txt", names=housing_names, sep='\s+')
#       7 housing=(housing-housing.mean())/housing.std()
# ...

# %% [markdown]
# ## Part 3 - Polynomial basis function
#
# * Generate a 2D dataset using a sine wave (10 values for `x` in the interval $[0, 10]$), perturbed by a small gaussian noise. *Note:* To generate the same data as I generated, use $y = 4sin(x) + \epsilon$ by setting the seed to 0
# * The Polynomial basis function that you will use is of the following form:
#     - $\phi_i(x)=x^i$
# * You will do this to create models of degrees 2, 4, and 9.
#     - Transform your original `x` into the design matrix $\Phi$ by applying the basis functions to each element of `x`
#     - For degree 2: $i\in[0,1,2]$, for degree 4: $i\in[0,1,2,3,4]$, and for degree 9: $i\in[0,1,2,...,9]$
#     - *This means that for each Degree you will create a different $\Phi$ and fit a different regression model.*
#
# * Plot the data and the prediction for each degree.
# * Which degree of polynomial works better to model this scenario?
#
# Example: Let's say that $$x=\begin{bmatrix} x_1=2 \\ x_2=3 \\ x_3=1 \end{bmatrix}$$
# Then for Degree 2 I will use the following basis functions: $\phi_0(x_j)=x_j^0, \phi_1(x_j)=x_j^1, \phi_2(x_j)=x_j^2$.
#
# In this case, $\Phi$ will look like:
# $$\Phi=\begin{bmatrix} \phi_0(x_1)=x_1^0 & \phi_1(x_1)=x_1^1 & \phi_2(x_1)=x_1^2 \\ \phi_0(x_2)=x_2^0 & \phi_1(x_2)=x_2^1 & \phi_2(x_2)=x_2^2 \\ \phi_0(x_3)=x_3^0 & \phi_1(x_3)=x_3^1 & \phi_2(x_3)=x_3^2 \end{bmatrix}$$
#
# Finally:
# $$\Phi=\begin{bmatrix} 1 & 2 & 4 \\ 1 & 3 & 9 \\ 1 & 1 & 1 \end{bmatrix}$$
#
# __*Important:* You have to code this exercise yourself.__

# %% [markdown]
# AQUI Ó

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================
# Utilities
# ============================================

def mse(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)


# ============================================
# Canonical polynomial basis
# ============================================

def calculate_phi(x, degree):

    phi = np.zeros((len(x), degree + 1))

    for i in range(degree + 1):
        phi[:, i] = x ** i

    return phi


def lr_pi_pol(x, y, degree):

    phi = calculate_phi(x, degree)

    w = np.linalg.solve(phi.T @ phi, phi.T @ y)

    return w, phi
d=3
condicionamento_canonico=[]
#=============================================
# Experiment
#=============================================
for m in range(10,800):
    x=np.linspace(-1,1,m)
    y=np.sin(x)+np.random.normal(0,1,x.size)
    w,lx=lr_pi_pol(x,y,d)
    condicionamento_canonico.append(np.linalg.cond(lx))

ms = np.arange(10,800)

plt.plot(ms, condicionamento_canonico)

plt.grid()
plt.show()


m=200
condicionamento_canonico=[]
cond_test=[]
#=============================================
# Experiment
#=============================================
for d in range(10,400):
    x=np.linspace(-1,1,m)
    y=np.sin(x)+np.random.normal(0,1,x.size)
    w,lx=lr_pi_pol(x,y,d)
    singular_values = np.linalg.svd(lx, compute_uv=False)
    cond_test.append(singular_values.max() / singular_values.min())
    condicionamento_canonico.append(np.linalg.cond(lx))

ms = np.arange(10,400)

plt.plot(ms, condicionamento_canonico)
plt.yscale("log")
plt.grid()
plt.show()

ms = np.arange(10,400)

plt.plot(ms, cond_test)
plt.yscale("log")
plt.grid()
plt.show()

# %%
condicionamento_canonico=[]
counter=0
d=3
jumps_in_d=[]
evil_ms=[]
for m in range(10,1000):
    counter+=1
    x=np.linspace(-1,1,m)
    y=np.sin(x)+np.random.normal(0,1,x.size)
    w,lx=lr_pi_pol(x,y,d)
    condicionamento_canonico.append(np.linalg.cond(lx))
    if counter>50:
        d+=2
        jumps_in_d.append(np.linalg.cond(lx))
        evil_ms.append(m)
        counter=0
    
ms = np.arange(10,1000)


plt.plot(ms,condicionamento_canonico)
plt.scatter(evil_ms,jumps_in_d,c="red",s=10)
plt.yscale("log")
plt.grid()
plt.show()

# %%
def calculate_phi(x, degree):

    phi = np.zeros((len(x), degree + 1))

    for i in range(degree + 1):
        phi[:, i] = x ** i

    return phi

def lr_pi_pol(x, y, degree):

    phi = calculate_phi(x, degree)

    w = np.linalg.solve(phi.T @ phi, phi.T @ y)

    return w, phi
m=10
n=10
d=10
cond_n=[]
for n in range(10,400):
    x=np.linspace(-1,1,m)
    y=np.linspace(-1,1,n)
    lx=calculate_phi(x,d)
    rx=np.linalg.pinv(lx)
    ly=calculate_phi(y,d)
    ly_rx=ly@rx
    singular_values=np.linalg.svd(ly_rx,compute_uv=False)
    cond_n.append(singular_values.max()/singular_values.min())


ms=np.arange(10,400)
plt.plot(ms,cond_n)


plt.grid()

plt.show()


m=10
n=200
d=10
cond_m=[]
for m in range(10,400):
    x=np.linspace(-1,1,m)
    y=np.linspace(-1,1,n)
    lx=calculate_phi(x,d)
    rx=np.linalg.pinv(lx)
    ly=calculate_phi(y,d)
    ly_rx=ly@rx
    singular_values=np.linalg.svd(ly_rx,compute_uv=False)
    cond_m.append(singular_values.max()/singular_values.min())

ms=np.arange(10,400)

plt.yscale("log")
plt.plot(ms,cond_m)
plt.grid()

plt.show()







m=400
n=200
d=10
cond_d=[]
for d in range(10,400):
    x=np.linspace(-1,1,m)
    y=np.linspace(-1,1,n)
    lx=calculate_phi(x,d)
    rx=np.linalg.pinv(lx)
    ly=calculate_phi(y,d)
    ly_rx=ly@rx
    singular_values=np.linalg.svd(ly_rx,compute_uv=False)
    cond_d.append(singular_values.max()/singular_values.min())

ms=np.arange(10,400)

plt.yscale("log")
plt.plot(ms,cond_d)
plt.grid()

plt.show()

# %%
m=10
n=10
d=10
cond_n=[]
evil_ms=[]
counter=0
jump_maybe=[]
for n in range(10,400):
    counter+=1
    x=np.linspace(-1,1,m)
    y=np.linspace(-1,1,n)
    lx=calculate_phi(x,d)
    rx=np.linalg.pinv(lx)
    ly=calculate_phi(y,d)
    ly_rx=ly@rx
    singular_values=np.linalg.svd(ly_rx,compute_uv=False)
    cond_n.append(singular_values.max()/singular_values.min())
    if counter>10:
        m+=1
        d+=1
        evil_ms.append(n)
        jump_maybe.append(singular_values.max()/singular_values.min())
        counter=0
    
ms=np.arange(10,400)
plt.plot(ms,cond_n)
plt.scatter(evil_ms,jump_maybe,c="red",s=10)
plt.yscale("log")
plt.grid()

plt.show()

# %%
m=50
d=10
n=100
x_train=np.linspace(-1,1,m)
x_test=np.linspace(-1.5,1.5,n)

y_train=np.sin(8*x_train)+0.05*rng.normal(0,1,m)
y_test=np.sin(8*x_test)+0.05*rng.normal(0,1,n)

w,lx=lr_pi_pol(x_train,y_train,d)



pol=np.polynomial.Polynomial(w)
y_pred_train=pol(x_train)


plt.plot(x_train,y_train)
plt.plot(x_train,y_pred_train)

plt.grid()
plt.show()

y_pred_test=pol(x_test)
plt.plot(x_test,y_test)
plt.plot(x_test,y_pred_test)
plt.grid()
plt.show()

# %%
m=50
d=10
n=100
x_train=np.linspace(0,1,m)
x_test=np.linspace(-1,0,n)

y_train=np.sin(2*np.pi*x_train)+0.05*rng.normal(0,1,m)
y_test=np.sin(2*np.pi*x_test)+0.05*rng.normal(0,1,n)

w,lx=lr_pi_pol(x_train,y_train,d)



pol=np.polynomial.Polynomial(w)
y_pred_train=pol(x_train)


plt.plot(x_train,y_train)
plt.plot(x_train,y_pred_train)

plt.grid()
plt.show()

y_pred_test=pol(x_test)
plt.plot(x_test,y_test)
plt.plot(x_test,y_pred_test)
plt.grid()
plt.show()

# %%
# ============================================
# Lagrange basis
# ============================================

def basis_lagrange(x_eval, basis_points):

    n_basis = len(basis_points)

    phi = np.ones((len(x_eval), n_basis))

    for k in range(n_basis):

        for i in range(n_basis):

            if i != k:

                phi[:, k] *= ((x_eval - basis_points[i]) /(basis_points[k] - basis_points[i]))

    return phi


def lr_lagrange(x, y, degree, interval=(-1, 1)):

    # equally spaced points defining the basis
    basis_points = np.linspace(interval[0],interval[1],degree + 1)

    phi = basis_lagrange(x, basis_points)

    w = np.linalg.solve(phi.T @ phi, phi.T @ y)

    return w, phi, basis_points


# ============================================
# Experiment
# ============================================

d = 3

errors_lagrange = []
errors_canonica = []

cond_lagrange = []
cond_canonica = []

for m in range(10, 10000,10):
    # data
    x_train = np.linspace(-1, 1, m)
    x_test = np.linspace(-0.5, 0.5, m)

    y_train = np.sin(x_train)
    y_test = np.sin(x_test)

    # ======================
    # Canonical basis
    # ======================

    w_poly, phi_poly = lr_pi_pol(x_train,y_train,d)

    cond_canonica.append(np.linalg.cond(phi_poly))

    y_pred_poly = (calculate_phi(x_test, d) @ w_poly)

    errors_canonica.append(mse(y_test, y_pred_poly))

    # ======================
    # Lagrange basis
    # ======================

    w_lag, phi_lag, basis_points = lr_lagrange(x_train,y_train,d,interval=(-1, 1))

    cond_lagrange.append(np.linalg.cond(phi_lag))

    y_pred_lag = (basis_lagrange(x_test,basis_points) @ w_lag)

    errors_lagrange.append(mse(y_test, y_pred_lag))


# ============================================
# Plots
# ============================================

plt.figure()
plt.plot(errors_canonica)
plt.title("Canonical Basis Error")
plt.xscale("log")
plt.show()

plt.figure()
plt.plot(errors_lagrange)
plt.title("Lagrange Basis Error")
plt.xscale("log")
plt.show()

plt.figure()
plt.plot(cond_canonica)
plt.title("Canonical Basis Conditioning")


plt.plot(cond_lagrange)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(0)

# ============================================
# Utilities
# ============================================

def mse(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)


# ============================================
# Canonical polynomial basis
# ============================================

def calculate_phi(x, degree):

    phi = np.zeros((len(x), degree + 1))

    for i in range(degree + 1):
        phi[:, i] = x ** i

    return phi


def lr_pi_pol(x, y, degree):

    phi = calculate_phi(x, degree)

    w = np.linalg.solve(
        phi.T @ phi,
        phi.T @ y
    )

    return w, phi


# ============================================
# Lagrange basis
# ============================================

def basis_lagrange(x_eval, basis_points):

    n_basis = len(basis_points)

    phi = np.ones((len(x_eval), n_basis))

    for k in range(n_basis):

        for i in range(n_basis):

            if i != k:

                phi[:, k] *= (
                    (x_eval - basis_points[i]) /
                    (basis_points[k] - basis_points[i])
                )

    return phi


def lr_lagrange(x, y, degree, interval=(-1,1)):

    k = np.arange(d+1)

    basis_points = np.cos(
    (2*k + 1) * np.pi / (2*(d+1))
)

    phi = basis_lagrange(
        x,
        basis_points
    )

    w = np.linalg.solve(
        phi.T @ phi,
        phi.T @ y
    )

    return w, phi, basis_points


# ============================================
# Dataset
# ============================================

m = 500
d = 50

x_train = np.linspace(-1, 1, m)
x_test = np.linspace(-1, 1, m)

y_train = np.sin(x_train)
y_test = np.sin(x_test)

# ============================================
# Tiny perturbation
# ============================================

epsilon = 1e-8

perturbation = rng.normal(
    0,
    epsilon,
    len(y_train)
)

y_train_perturbed = (
    y_train + perturbation
)

# ============================================
# Canonical basis
# ============================================

w_poly_1, phi_poly = lr_pi_pol(
    x_train,
    y_train,
    d
)

w_poly_2, _ = lr_pi_pol(
    x_train,
    y_train_perturbed,
    d
)

pred_poly_1 = (
    calculate_phi(x_test, d)
    @ w_poly_1
)

pred_poly_2 = (
    calculate_phi(x_test, d)
    @ w_poly_2
)

poly_sensitivity = np.linalg.norm(
    pred_poly_1 - pred_poly_2
)

# ============================================
# Lagrange basis
# ============================================

w_lag_1, phi_lag, basis_points = lr_lagrange(
    x_train,
    y_train,
    d
)

w_lag_2, _, _ = lr_lagrange(
    x_train,
    y_train_perturbed,
    d
)

pred_lag_1 = (
    basis_lagrange(
        x_test,
        basis_points
    ) @ w_lag_1
)

pred_lag_2 = (
    basis_lagrange(
        x_test,
        basis_points
    ) @ w_lag_2
)

lag_sensitivity = np.linalg.norm(
    pred_lag_1 - pred_lag_2
)

# ============================================
# Print comparison
# ============================================

print("Conditioning canonical:")
print(np.linalg.cond(phi_poly))

print()

print("Conditioning lagrange:")
print(np.linalg.cond(phi_lag))

print()

print("Prediction sensitivity canonical:")
print(poly_sensitivity)

print()

print("Prediction sensitivity lagrange:")
print(lag_sensitivity)

# ============================================
# Plot prediction perturbations
# ============================================

plt.figure(figsize=(10,5))

plt.plot(
    x_test,
    pred_poly_1,
    label="Canonical original"
)

plt.plot(
    x_test,
    pred_poly_2,
    linestyle="--",
    label="Canonical perturbed"
)

plt.legend()
plt.title("Canonical Basis Sensitivity")

plt.show()

plt.figure(figsize=(10,5))

plt.plot(
    x_test,
    pred_lag_1,
    label="Lagrange original"
)

plt.plot(
    x_test,
    pred_lag_2,
    linestyle="--",
    label="Lagrange perturbed"
)

plt.legend()
plt.title("Lagrange Basis Sensitivity")

plt.show()
# Out:
# Conditioning canonical:
# 9.807624816196832e+16
#
# Conditioning lagrange:
# 4.169382892165507
#
# Prediction sensitivity canonical:
# 1.2395682839042942e-07
#
# Prediction sensitivity lagrange:
# 6.598221736930121e-08

# %% [markdown]
# ## Part 4 - Polynomial basis function
#
# For this part you will replicate the previous part but using the existing functions from sklearn!
#
# * Use the same data as the previous part.
# * Use sklearn's Linear Regression estimator together with a Polynomial transform to make a Linear regression with a polynomial basis.
#
# *Note:* To generate the same data as I generated, use $y = 4sin(x) + \epsilon$ by setting the seed to 0

# %%
# your code here
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


rng = np.random.default_rng(0)
x = np.sort(rng.uniform(0,11,10))
noise = rng.normal(0,1,10)
y = 4*np.sin(x)
y_noise=y+noise
X = x.reshape(-1,1)


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.1,shuffle=False)
print(X_test)
poly2=PolynomialFeatures(degree=2)
poly4=PolynomialFeatures(degree=4)
poly9=PolynomialFeatures(degree=9)
x_train2=poly2.fit_transform(X_train)
x_test2=poly2.transform(X_test)
x_train4=poly4.fit_transform(X_train)
x_test4=poly4.transform(X_test)
x_train9=poly9.fit_transform(X_train)
x_test9=poly9.transform(X_test)
model2=LinearRegression()
model4=LinearRegression()
model9=LinearRegression()
model2.fit(x_train2,y_train)
model4.fit(x_train4,y_train)
model9.fit(x_train9,y_train)
y_2=model2.predict(x_train2)
y_4=model4.predict(x_train4)
y_9=model9.predict(x_train9)

y_predict2=model2.predict(x_test2)
y_predict4=model4.predict(x_test4)
y_predict9=model9.predict(x_test9)

#só ta deixando bonito lindo maravilhoso, ignore
x_plot=np.linspace(x.min(),x.max(),300)
x_9plot=np.linspace(x[:9].min(),x[:9].max(),300)
spl = make_interp_spline(x, y)
y_smooth = spl(x_plot)

spl_2 = make_interp_spline(x[:9], y_2)
y_2 = spl_2(x_9plot)

spl_4 = make_interp_spline(x[:9], y_4)
y_4 = spl_4(x_9plot)

spl_9 = make_interp_spline(x[:9], y_9)
y_9 = spl_9(x_9plot)

#plot começa aqui
plt.plot(x_9plot,y_2,label="grau 2",color="orange")
plt.plot(x_9plot,y_4,label="grau 4",color="green")
plt.plot(x_9plot,y_9,label="grau 9",color="red")

plt.scatter(x,y_noise, label="pontos reais")
plt.scatter(x[9],y_predict2,label="10ºponto grau 2")
plt.scatter(x[9],y_predict4,label="10ºponto grau 4")
plt.scatter(x[9],y_predict9,label="10ºponto grau 9")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlim(0)
plt.show()
# Out:
# [[10.28579666]]
